# %% [markdown]
# ## Style and Color

# %%
import seaborn as sns 
# %matplotlib inline 

tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Setting particular styles 

sns.set_style('darkgrid')
sns.countplot(x='sex',data=tips)

# %%
# Size and Aspects. It's possible to control the size of your plots by passing different params 

import matplotlib.pyplot as plt


plt.figure(figsize=(12,3))
sns.countplot(x='sex',data=tips)

# %%
# Scale and Context (Large scale for a poster print)

sns.set_context('poster', font_scale=1) # Play with the scale to get the desired size
sns.countplot(x='sex',data=tips)

# %%
sns.lmplot(x='total_bill',y='tip', data=tips, hue='sex', palette='coolwarm')

# The palette codes are all in the documentation
